# %% [markdown]
# # Accessing and exploration of the AACT database

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import os
import requests
from sqlalchemy import create_engine

# %% [markdown]
# ## Accessing AACT database

# %%
# Connect to database
aact_host=os.environ["aact_host"]
aact_port=os.environ["aact_port"]
db_name=os.environ["db_name"]
aact_username=os.environ["aact_username"]
aact_password=os.environ["aact_password"]

db_string = "postgres://{}:{}@{}:{}/{}". \
    format(aact_username, aact_password, aact_host, aact_port, db_name)

db = create_engine(db_string)

conn = db.connect()

# %%
# Perform count of studies
q = "select count(*) from studies;"

conn.execute(q).fetchall()
# Out:
# [(306660,)]

# %% [markdown]
# ## Explore data relevant to patients
# The AACT database contains ___ tables with ___ data. In order to
# We'll be extracting important information that will be important to patients. I wanted to prioritize which sections will be most important for patients for understanding whether they will be eligible for a trial. We concentrated on information such as the active participation period, the follow-up period, and eligibility criteria.

# %% [markdown]
# We designed the categories from our manual analysis of 100 sample trial descriptions. The categories include the information most vital to patients’ understanding of a trial: active participation period, follow up period, and eligibility criteria, to name a few.
#
# Next we labelled each category with its datatype, and tagged each with keywords that appear in or near the information we want.
#
# To assess the validity of the keywords we chose, we conducted frequency evaluations of each indicator. Here’s a sample of what the output looks like:

# %%
# Perform selection of brief_summary
condition = "carcinoma, hepatocellular"

q = """SELECT studies.nct_id,
            e.gender,
            e.minimum_age,
            e.maximum_age,
            e.healthy_volunteers,
            e.population,
            e.criteria AS eligibility_criteria,
            bs.description AS brief_summary,
            
            c.downcase_name AS condition
        FROM studies
        FULL OUTER JOIN brief_summaries bs
            ON studies.nct_id=bs.nct_id
        FULL OUTER JOIN eligibilities e
            ON studies.nct_id=e.nct_id
        INNER JOIN conditions c
            ON studies.nct_id=c.nct_id
        INNER JOIN browse_conditions bc
            ON studies.nct_id=bc.nct_id
        WHERE c.downcase_name='{}'
        LIMIT 5;
        """.format(condition)

r = conn.execute(q).fetchall()
col_names = conn.execute(q).keys()

pd.DataFrame(r, columns=col_names)
# Out:
#         nct_id gender minimum_age maximum_age healthy_volunteers population  \
# 0  NCT02847767    All    18 Years         N/A                 No
# 1  NCT02847767    All    18 Years         N/A                 No
# 2  NCT02794337    All    18 Years         N/A                 No
# 3  NCT02794337    All    18 Years         N/A                 No
# 4  NCT01605734    All    18 Years    75 Years                 No
#
#                                 eligibility_criteria  \
# 0  \n        Inclusion Criteria:\n\n        All t...
# 1  \n        Inclusion Criteria:\n\n        All t...
# 2  \n        Inclusion Criteria:\n\n          -  ...
# 3  \n        Inclusion Criteria:\n\n          -  ...
# 4  \n        Inclusion Criteria:\n\n          -  ...
#
#                                        brief_summary  \
# 0  \n      The high dose per fraction (>10Gy/frac...
# 1  \n      The high dose per fraction (>10Gy/frac...
# 2  \n      Vast majority of patients with hepatoc...
# 3  \n      Vast majority of patients with hepatoc...
# 4  \n      TACE is widely used in patients with u...
#
#                    condition
# 0  carcinoma, hepatocellular
# 1  carcinoma, hepatocellular
# 2  carcinoma, hepatocellular
# 3  carcinoma, hepatocellular
# 4  carcinoma, hepatocellular

# %%
# Identify total number of trials for all with condition
q = """SELECT count(DISTINCT studies.nct_id)
        FROM studies
        FULL OUTER JOIN brief_summaries bs
            ON studies.nct_id=bs.nct_id
        FULL OUTER JOIN eligibilities e
            ON studies.nct_id=e.nct_id
        INNER JOIN conditions c
            ON studies.nct_id=c.nct_id
        INNER JOIN browse_conditions bc
            ON studies.nct_id=bc.nct_id
        WHERE c.downcase_name='{}';
        """.format(condition)

r = conn.execute(q).fetchall()
r[0][0]
# Out:
# 222

# %%
# Extract information from all HCC trials
# Perform selection of brief_summary
condition = "carcinoma, hepatocellular"

q = """SELECT studies.nct_id,
            e.gender,
            e.minimum_age,
            e.maximum_age,
            e.healthy_volunteers,
            e.population,
            e.criteria AS eligibility_criteria,
            bs.description AS brief_summary,
            c.downcase_name AS condition
        FROM studies
        FULL OUTER JOIN brief_summaries bs
            ON studies.nct_id=bs.nct_id
        FULL OUTER JOIN eligibilities e
            ON studies.nct_id=e.nct_id
        INNER JOIN conditions c
            ON studies.nct_id=c.nct_id
        INNER JOIN browse_conditions bc
            ON studies.nct_id=bc.nct_id
        WHERE c.downcase_name='{}';
        """.format(condition)

r = conn.execute(q).fetchall()
col_names = conn.execute(q).keys()

df = pd.DataFrame(r, columns=col_names)

# Drop duplicate rows
df.drop_duplicates(inplace=True)

df
# Out:
#           nct_id gender minimum_age maximum_age healthy_volunteers  \
# 0    NCT02847767    All    18 Years         N/A                 No
# 2    NCT02794337    All    18 Years         N/A                 No
# 4    NCT01605734    All    18 Years    75 Years                 No
# 6    NCT01594125    All    20 Years         N/A                 No
# 8    NCT01668134    All    18 Years         N/A                 No
# 11   NCT01556815    All    18 Years    80 Years                 No
# 22   NCT01078415    All    18 Years         N/A                 No
# 24   NCT02878109    All    18 Years         N/A                 No
# 26   NCT02847468    All    18 Years    99 Years                 No
# 28   NCT02115373    All    18 Years         N/A                 No
# 30   NCT03941873    All    18 Years         N/A                 No
# 31   NCT01040559    All    18 Years         N/A                 No
# 33   NCT00987935    All    18 Years         N/A                 No
# 35   NCT03766555    All    18 Years         N/A                 No
# 37   NCT03418922    All    20 Years         N/A                 No
# 39   NCT03191123    All    20 Years    75 Years                 No
# 41   NCT03168152    All    18 Years         N/A                 No
# 43   NCT02308319    All    18 Years         N/A                 No
# 46   NCT01327521    All    18 Years         N/A                 No
# 48   NCT02973204    All    18 Years         N/A                 No
# 51   NCT01306058    All    18 Years    99 Years                 No
# 59   NCT02848638    All    18 Years    85 Years                 No
# 61   NCT01411436    All         N/A         N/A                 No
# 63   NCT02576964    All    18 Years    75 Years                 No
# 65   NCT02403544    All    18 Years    65 Years                 No
# 67   NCT01915602    All    18 Years         N/A                 No
# 69   NCT01915589    All    18 Years         N/A                 No
# 71   NCT03291379    All    18 Years         N/A                 No
# 73   NCT02069041    All    20 Years    75 Years                 No
# 75   NCT02715362    All    18 Years    69 Years                 No
# ..           ...    ...         ...         ...                ...
# 510  NCT00116454    All    18 Years    75 Years                 No
# 514  NCT00662246    All    18 Years         N/A                 No
# 516  NCT00920192    All    18 Years         N/A                 No
# 518  NCT00108953    All    18 Years         N/A                 No
# 520  NCT00105443    All    18 Years         N/A                 No
# 522  NCT00082082    All    18 Years         N/A                 No
# 524  NCT00081900    All    18 Years         N/A                 No
# 526  NCT00080236    All    18 Years         N/A                 No
# 528  NCT00703365    All    18 Years         N/A                 No
# 530  NCT00919009    All    20 Years         N/A                 No
# 532  NCT00701168    All    19 Years         N/A
# 534  NCT00855218    All    18 Years         N/A                 No
# 536  NCT00044512    All    18 Years         N/A                 No
# 538  NCT00034333    All    18 Years    80 Years                 No
# 540  NCT00936689    All    18 Years         N/A                 No
# 542  NCT00687778    All    18 Years    90 Years                 No
# 550  NCT00699374    All    18 Years         N/A                 No
# 552  NCT00056992    All         N/A         N/A                 No
# 554  NCT00763776    All    18 Years         N/A                 No
# 558  NCT00247728    All    18 Years    75 Years                 No
# 560  NCT00122876    All    18 Years         N/A                 No
# 563  NCT00901901    All    18 Years         N/A                 No
# 565  NCT00582400    All    18 Years         N/A                 No
# 567  NCT00563095    All    18 Years         N/A
# 569  NCT03808766    All    19 Years         N/A                 No
# 571  NCT00437424    All    18 Years         N/A                 No
# 573  NCT00355212    All         N/A         N/A                 No
# 576  NCT00490685    All    18 Years         N/A                 No
# 578  NCT00006332    All    18 Years         N/A                 No
# 580  NCT00243841    All    18 Years         N/A                 No
#
#                                             population  \
# 0
# 2
# 4
# 6
# 8
# 11
# 22
# 24   The target population is adults with a hepatoc...
# 26
# 28
# 30
# 31
# 33
# 35
# 37
# 39
# 41
# 43
# 46
# 48   40 patients newly diagnosed NET patients refer...
# 51
# 59   Patients (18-85 years old), who have hepatocel...
# 61   The target population of this study is patient...
# 63
# 65
# 67
# 69
# 71
# 73
# 75
# ..                                                 ...
# 510
# 514
# 516
# 518
# 520
# 522
# 524
# 526
# 528
# 530
# 532
# 534
# 536
# 538
# 540
# 542  100 patients with newly diagnosed tumors, whic...
# 550
# 552
# 554
# 558
# 560
# 563
# 565
# 567
# 569
# 571
# 573
# 576
# 578
# 580
#
#                                   eligibility_criteria  \
# 0    \n        Inclusion Criteria:\n\n        All t...
# 2    \n        Inclusion Criteria:\n\n          -  ...
# 4    \n        Inclusion Criteria:\n\n          -  ...
# 6    \n        Inclusion criteria:\n\n          1. ...
# 8    \n        Inclusion Criteria:\n\n          -  ...
# 11   \n        Inclusion Criteria:\n\n          -  ...
# 22   \n        Inclusion Criteria:\n\n          -  ...
# 24   \n        Inclusion Criteria:\n\n          -  ...
# 26   \n        Inclusion Criteria:\n\n          -  ...
# 28   \n        Inclusion Criteria:\n\n          -  ...
# 30   \n        Inclusion Criteria:Each patient elig...
# 31   \n        Inclusion Criteria:\n\n          -  ...
# 33   \n        Inclusion criteria:\n\n          1. ...
# 35   \n        Inclusion Criteria:\n\n          -  ...
# 37   \n        Inclusion Criteria:\n\n          -  ...
# 39   \n        Inclusion Criteria:\n\n          -  ...
# 41   \n        Inclusion Criteria:\n\n          -  ...
# 43   \n        Inclusion Criteria:\n\n          -  ...
# 46   \n        Inclusion Criteria:\n\n          -  ...
# 48   \n        Inclusion Criteria:\n\n          -  ...
# 51   \n        -  INCLUSION CRITERIA:\n\n          ...
# 59   \n        Inclusion Criteria:\n\n          1. ...
# 61   \n        Inclusion Criteria:\n\n          -  ...
# 63   \n        Inclusion Criteria:\n\n          -  ...
# 65   \n        Criteria:\n\n        Inclusion Crite...
# 67   \n        Inclusion Criteria:\n\n        Eligi...
# 69   \n        Inclusion Criteria:\n\n        Eligi...
# 71   \n        Inclusion Criteria:\n\n          1. ...
# 73   \n        Inclusion Criteria:\n\n          -  ...
# 75   \n        Inclusion Criteria:\n\n          -  ...
# ..                                                 ...
# 510  \n        Inclusion Criteria:\n\n          -  ...
# 514  \n        Inclusion Criteria:\n\n          -  ...
# 516  \n        Inclusion Criteria:\n\n          -  ...
# 518  \n        Inclusion Criteria:\n\n          -  ...
# 520  \n        Inclusion Criteria:\n\n          -  ...
# 522  \n        Inclusion Criteria:\n\n          -  ...
# 524  \n        Inclusion Criteria:\n\n          -  ...
# 526  \n        Inclusion Criteria:\n\n          -  ...
# 528  \n        Inclusion Criteria:\n\n          -  ...
# 530  \n        Inclusion Criteria:\n\n          -  ...
# 532  \n        Inclusion Criteria:\n\n          -  ...
# 534  \n        Inclusion Criteria:\n\n          -  ...
# 536  \n        Inclusion Criteria:\n\n          -  ...
# 538  \n        Patients may be enrolled into this p...
# 540  \n        Inclusion Criteria:\n\n          -  ...
# 542  \n        Inclusion Criteria:\n\n          -  ...
# 550  \n        Inclusion Criteria:\n\n          -  ...
# 552  \n        -  Histologically confirmed diagnosi...
# 554  \n        Inclusion Criteria:\n\n          -  ...
# 558  \n        Inclusion Criteria:\n\n          -  ...
# 560  \n        Inclusion Criteria:\n\n          -  ...
# 563  \n        Inclusion Criteria:\n\n          -  ...
# 565  \n        Inclusion Criteria:\n\n          -  ...
# 567  \n        Inclusion Criteria:\n\n          -  ...
# 569  \n        Inclusion Criteria:\n\n          1. ...
# 571  \n        Inclusion Criteria:\n\n          -  ...
# 573  \n        Inclusion Criteria:\n\n          -  ...
# 576  \n        Inclusion Criteria:\n\n        Patie...
# 578  \n        Inclusion Criteria:\n\n          -  ...
# 580  \n        Inclusion Criteria:\n\n        Evalu...
#
#                                          brief_summary  \
# 0    \n      The high dose per fraction (>10Gy/frac...
# 2    \n      Vast majority of patients with hepatoc...
# 4    \n      TACE is widely used in patients with u...
# 6    \n      The aim of the study is to investigate...
# 8    \n      This study is being done to determine ...
# 11   \n      Transarterial chemoembolization (TACE)...
# 22   \n      The purpose of this study is to evalua...
# 24   \n      This study is conducted to evaluate dy...
# 26   \n      Hepatocellular carcinoma (HCC) is the ...
# 28   \n      This is a Phase 1b/2, multicenter, sin...
# 30   \n      The purpose of this study is to evalua...
# 31   \n      The purpose of this study is to determ...
# 33   \n      This study is to evaluate the safety, ...
# 35   \n      We propose a randomized controlled stu...
# 37   \n      The primary objective of this study is...
# 39   \n      This clinical trial aims to compare he...
# 41   \n      This is a randomized phase II study co...
# 43   \n      Antiviral therapy for HBV may play an ...
# 46   \n      Primary Objective:\n\n      To compare...
# 48   \n      Background Treatment and control of ca...
# 51   \n      Background:\n\n      Sorafenib is a dr...
# 59   \n      The primary goal of the study is to se...
# 61   \n      This study is a regulatory post-market...
# 63   \n      This study will evaluate the efficacy ...
# 65   \n      This is a phase I study to evaluate th...
# 67   \n      This is a study to investigate the pot...
# 69   \n      This is a study to investigate the pot...
# 71   \n      This is a pilot, open label single arm...
# 73   \n      The main purpose of this study is to d...
# 75   \n      Intravenous infusion of CART cells in ...
# ..                                                 ...
# 510  \n      The recurrence of hepatocellular carci...
# 514  \n      The radical treatment for Hepatocellul...
# 516  \n      The purpose of this study is to assess...
# 518  \n      The purpose of this study is to evalua...
# 520  \n      The purpose of the study is: Find out ...
# 522  \n      The objective of this Phase II trial i...
# 524  \n      Approximately 18-45 patients with Hepa...
# 526  \n      The purpose of the study is to test th...
# 528  \n      This study is to evaluate the efficacy...
# 530  \n      Most HCC patients are diagnosed at adv...
# 532  \n      The purpose of this protocol is to pro...
# 534  \n      This study will look at whether our dr...
# 536  \n      Evaluate anti-cancer activity (e.g. pr...
# 538  \n      MTC-DOX is Doxorubicin or DOX, a chemo...
# 540  \n      Background\n\n      Hepatic intra-arte...
# 542  \n      F18-FDG is the widely used PET tracer ...
# 550  \n      The study will evaluate the efficacy a...
# 552  \n      Amino acid deprivation therapy is an e...
# 554  \n      To identify the most efficient parench...
# 558  \n      The purpose of this study is to evalua...
# 560  \n      The purpose of this study is to determ...
# 563  \n      This is a randomized trial to evaluate...
# 565  \n      The purpose of this study is: evaluate...
# 567  \n      Primary: To compare the efficacy of TA...
# 569  \n      Hepatocellular carcinoma (HCC) is one ...
# 571  \n      The primary purpose of this protocol i...
# 573  \n      Ethanol injection has been for many ye...
# 576  \n      The aim of the study is to evaluate, a...
# 578  \n      Hepatocellular carcinoma (HCC) is a de...
# 580  \n      The purpose of this study is to determ...
#
#                      condition
# 0    carcinoma, hepatocellular
# 2    carcinoma, hepatocellular
# 4    carcinoma, hepatocellular
# 6    carcinoma, hepatocellular
# 8    carcinoma, hepatocellular
# 11   carcinoma, hepatocellular
# 22   carcinoma, hepatocellular
# 24   carcinoma, hepatocellular
# 26   carcinoma, hepatocellular
# 28   carcinoma, hepatocellular
# 30   carcinoma, hepatocellular
# 31   carcinoma, hepatocellular
# 33   carcinoma, hepatocellular
# 35   carcinoma, hepatocellular
# 37   carcinoma, hepatocellular
# 39   carcinoma, hepatocellular
# 41   carcinoma, hepatocellular
# 43   carcinoma, hepatocellular
# 46   carcinoma, hepatocellular
# 48   carcinoma, hepatocellular
# 51   carcinoma, hepatocellular
# 59   carcinoma, hepatocellular
# 61   carcinoma, hepatocellular
# 63   carcinoma, hepatocellular
# 65   carcinoma, hepatocellular
# 67   carcinoma, hepatocellular
# 69   carcinoma, hepatocellular
# 71   carcinoma, hepatocellular
# 73   carcinoma, hepatocellular
# 75   carcinoma, hepatocellular
# ..                         ...
# 510  carcinoma, hepatocellular
# 514  carcinoma, hepatocellular
# 516  carcinoma, hepatocellular
# 518  carcinoma, hepatocellular
# 520  carcinoma, hepatocellular
# 522  carcinoma, hepatocellular
# 524  carcinoma, hepatocellular
# 526  carcinoma, hepatocellular
# 528  carcinoma, hepatocellular
# 530  carcinoma, hepatocellular
# 532  carcinoma, hepatocellular
# 534  carcinoma, hepatocellular
# 536  carcinoma, hepatocellular
# 538  carcinoma, hepatocellular
# 540  carcinoma, hepatocellular
# 542  carcinoma, hepatocellular
# 550  carcinoma, hepatocellular
# 552  carcinoma, hepatocellular
# 554  carcinoma, hepatocellular
# 558  carcinoma, hepatocellular
# 560  carcinoma, hepatocellular
# 563  carcinoma, hepatocellular
# 565  carcinoma, hepatocellular
# 567  carcinoma, hepatocellular
# 569  carcinoma, hepatocellular
# 571  carcinoma, hepatocellular
# 573  carcinoma, hepatocellular
# 576  carcinoma, hepatocellular
# 578  carcinoma, hepatocellular
# 580  carcinoma, hepatocellular
#
# [222 rows x 9 columns]

# %% [markdown]
# ## Process text

# %%
def clean_text(text):
    
    elements_to_remove = [':',
                           '-',
                           '\n',
                          '\t',
                          ]
    for element in elements_to_remove:
        text = text.replace(element, '')
    
    return text.lower()
    
df.eligibility_criteria.apply(clean_text)[0]
# Out:
# "        inclusion criteria        all the following criteria must be met          1. age > 18 years old          2. multiphase ct scan and/or mri of the liver within 8 weeks of radiation planning             demonstrating                 liver tumours < 5 cm                 no more than 2 discrete liver tumours                 normal liver > 700 cc          3. patients must have hcc diagnosed by either i) pathological confirmation, or ii)             intrahepatic vascular enhancement of the lesion demonstrated by at least two imaging             modalities, or iii) intrahepatic vascular enhancement of the lesion demonstrated by             one imaging modality if afp > 200 in the setting of liver cirrhosis or chronic             hepatitis b without cirrhosis (easl consensus guidelines [2])          4. liver hcc must be deemed unresectable as determined by an experienced hepatobiliary             surgeon, or the patient must be medically inoperable or refuse surgery,          5. patients must be discussed in a multidisciplinary setting, with representatives from             medical oncology, radiation oncology, surgery, interventional radiology, and             hepatology. patients must be considered ineligible for standard local treatments,             including surgery, liver transplantation, radiofrequency ablation, and targeted             biologics. some subjects could be potential candidates for sorafenib but normally this             treatment is not considered before all local treatment options have been considered,             as the response rate to sorafenib is low (2% in the sharp study). patients might be             candidates for sorafenib after progression on the study treatment or if they do not             want to participate and in both cases they will be referred to a medical oncologist.             patients may have received prior tace and had an incomplete response. ineffective or             incomplete tace is defined as incomplete filling by lipiodoldoxorubicin mixture used             by either angiography or ct ≥1 month after tace or by increasing alphafetoprotein             level. patients must have recovered from the effects of previous therapies before sbrt             with a minimum 4week period between tace and sbrt.          6. eastern clinical oncology group performance status 0, 1, or 2 (appendix iii), or a             karnofsky performance status of ≥ 60 (appendix iv)          7. adequate organ function as assessed by the following blood work                 hemoglobin ≥ 90 g/l                 absolute neutrophil count ≥ 1.0 bil/l                 platelets ≥ 50 bil/l                 ast and alt not to exceed 3x upper limit of normal          8. childturcottepugh assessment within 8 weeks of treatment date (appendix ii)                 bilirubin ≤ 3 mg/dl (< 50 µmol/l)                 albumin above 28 g/l                 inr < 1.7 and/or correctable with vitamin k (unless on anticoagulation therapy)                 no ascites or encephalopathy                 childturcottepugh score must be ≤ 7          9. bclc stage b or c (portal venous invasion or liver hilum nodal disease only; (appendix             i)         10. life expectancy > 6 months         11. no chemotherapy or systemic therapy concurrent with radiotherapy         12. previous treatment(s) with radiofrequency ablation, surgery, tace, y90, percutaneous             ethanol injection, or chemotherapy are not exclusion criteria provided that recurrence             or lack of tumour response has been documented. patients who decline, or not eligible             for, these treatments will also be considered eligible.         13. patient signs a studyspecific informed consent form. if the patient's mental status             precludes this, written informed consent may be given by the patient's legal             representative. a translator will be provided if the patient has a language barrier.         14. treatment plans meet acceptab ...

# %% [markdown]
# ## Tokenize words and take frequencies using nltk

# %%
from nltk.tokenize import word_tokenize
from nltk import bigrams
from nltk.corpus import stopwords
import matplotlib.pyplot as plt

# %%
def remove_stopwords(text, stopwords):
    return [word for word in text if word not in stopwords]

stop_words = set(stopwords.words('english'))

df.eligibility_criteria.apply(clean_text).apply(word_tokenize).apply(remove_stopwords, stopwords=stop_words)
# Out:
# 0      [inclusion, criteria, following, criteria, mus...
# 2      [inclusion, criteria, diagnosis, hcc, ., tissu...
# 4      [inclusion, criteria, patients, newly, diagnos...
# 6      [inclusion, criteria, 1., histologically/cytol...
# 8      [inclusion, criteria, age, ≥, 18, karnofsky, p...
# 11     [inclusion, criteria, patients, newly, diagnos...
# 22     [inclusion, criteria, hcc, diagnosed, positive...
# 24     [inclusion, criteria, patients, least, 18, yea...
# 26     [inclusion, criteria, patient, older, 18, year...
# 28     [inclusion, criteria, histologically, confirme...
# 30     [inclusion, criteriaeach, patient, eligible, p...
# 31     [inclusion, criteria, hepatocellular, carcinom...
# 33     [inclusion, criteria, 1., hepatocellular, carc...
# 35     [inclusion, criteria, age, >, 18, years, hcc, ...
# 37     [inclusion, criteria, participants, must, conf...
# 39     [inclusion, criteria, clinical, diagnosis, hep...
# 41     [inclusion, criteria, patients, hepatocellular...
# 43     [inclusion, criteria, hepatocellular, carcinom...
# 46     [inclusion, criteria, confirmed, hepatocellula...
# 48     [inclusion, criteria, one, mentioned, diseases...
# 51     [inclusion, criteria, patients, must, histopat...
# 59     [inclusion, criteria, 1., uwmc, patients, 18, ...
# 61     [inclusion, criteria, patients, received, nexa...
# 63     [inclusion, criteria, adults, 18, 75, years, a...
# 65     [criteria, inclusion, criteria, kps≥80, ., lif...
# 67     [inclusion, criteria, eligibility, criteria, r...
# 69     [inclusion, criteria, eligibility, criteria, r...
# 71     [inclusion, criteria, 1., male, female, adults...
# 73     [inclusion, criteria, histological, cytologica...
# 75     [inclusion, criteria, gpc3, expression, positi...
#                              ...
# 510    [inclusion, criteria, men, women, ,, aged, 18,...
# 514    [inclusion, criteria, hcc, diagnosed, (, ), pr...
# 516    [inclusion, criteria, signed, informed, consen...
# 518    [inclusion, criteria, patients, life, expectan...
# 520    [inclusion, criteria, ages, eligible, study, 1...
# 522    [inclusion, criteria, signed, written, informe...
# 524    [inclusion, criteria, histologically, proven, ...
# 526    [inclusion, criteria, minimum, adult, age, exc...
# 528    [inclusion, criteria, patient, least, 18, year...
# 530    [inclusion, criteria, patients, must, provide,...
# 532    [inclusion, criteria, confirmed, diagnosis, pr...
# 534    [inclusion, criteria, unresectable, ,, multino...
# 536    [inclusion, criteria, histologically, cytologi...
# 538    [patients, may, enrolled, protocol, following,...
# 540    [inclusion, criteria, diagnosis, hcc, based, g...
# 542    [inclusion, criteria, patients, newly, diagnos...
# 550    [inclusion, criteria, histologicallyconfirmed,...
# 552    [histologically, confirmed, diagnosis, hepatoc...
# 554    [inclusion, criteria, child, liver, cirrhosis,...
# 558    [inclusion, criteria, patients, voluntarily, g...
# 560    [inclusion, criteria, diagnosis, primary, hepa...
# 563    [inclusion, criteria, patients, >, 18, years, ...
# 565    [inclusion, criteria, signed, informed, consen...
# 567    [inclusion, criteria, confirmed, hepatocellula...
# 569    [inclusion, criteria, 1., age, 18, years, 2., ...
# 571    [inclusion, criteria, subjects, biopsy, proven...
# 573    [inclusion, criteria, included, cirrhotic, pat...
# 576    [inclusion, criteria, patients, advanced/inope...
# 578    [inclusion, criteria, patients, definite, diag...
# 580    [inclusion, criteria, evaluation, surgery, and...
# Name: eligibility_criteria, Length: 222, dtype: object

# %%
bigrams = df['eligibility_criteria'].apply(clean_text). \
    apply(word_tokenize).  \
    apply(remove_stopwords, stopwords=stop_words). \
    apply(lambda row: list(bigrams(row))). \
    apply(pd.Series).stack().reset_index(drop=True) # Turn series of lists into stacked series

# %%
# Bigram frequencies
val_counts = bigrams.value_counts()[:100]

plt.figure(figsize=(12,6))
plt.bar(val_counts.index.map(str), val_counts.values);

# %%
bigrams.value_counts()[6:100]
# Out:
# (., patients)                 121
# (4, weeks)                    120
# (performance, status)         102
# (6, months)                   102
# (18, years)                    85
# (., exclusion)                 78
# (life, expectancy)             77
# (criteria, 1.)                 77
# ((, ))                         75
# (patients, must)               73
# (3, months)                    69
# (dose, study)                  67
# (criteria, patients)           66
# (first, dose)                  66
# (days, prior)                  65
# (within, 4)                    64
# (least, one)                   62
# (upper, limit)                 62
# (limit, normal)                59
# (written, informed)            59
# (oncology, group)              59
# (study, drug)                  58
# (prior, study)                 58
# (childpugh, class)             58
# (eastern, cooperative)         57
# (cooperative, oncology)        57
# (weeks, prior)                 56
# (portal, vein)                 54
# (therapy, ,)                   53
# (study, entry)                 53
#                              ...
# (30, days)                     38
# (patient, must)                37
# (within, last)                 37
# (virus, ()                     37
# (2, weeks)                     36
# (basal, cell)                  36
# (status, 0)                    36
# (b, c)                         36
# (., 5.)                        35
# (chemotherapy, ,)              35
# (therapy, .)                   35
# (., history)                   35
# (child, pugh)                  34
# (grade, 2)                     34
# (ecog, performance)            34
# (central, nervous)             34
# (radiofrequency, ablation)     34
# (,, liver)                     34
# (prior, systemic)              34
# (nervous, system)              34
# (12, weeks)                    34
# (surgical, resection)          34
# (0, 1)                         34
# (e.g, .)                       34
# (., 4.)                        34
# (locoregional, therapy)        34
# (therapy, ()                   34
# ((, ecog)                      33
# (carcinoma, ,)                 33
# (,, except)                    33
# Length: 94, dtype: int64

# %% [markdown]
# Analysis of the top most frequent bigrams from eligibilites of 222 HCC trials showed common features from these trials. These bigrams can now be used to identify general wording structures. For instance, lengths of time (eg, "2 weeks" or "4 weeks") or can be extracted from these
#
# - 4 weeks, 2 weeks, 30 days,
# - performance status
# - 6 months, 8 months
# - 18 years
# - within 4
# - basal cell
# - upper limit, limit normal
# - life expectancy: life expectancy of at least 3 months
# - chemotherapy
# - prior studies
# - portal vein
# - patients must
# - patient must
# - with the last
# - virus
# - grade 2
# - child pugh: Child-Pugh class A
# - ECOG performance
# - prior systemic
# - nervous system
# - locoregional therapy
# - ECOG
# -

# %%
df.loc[df['eligibility_criteria'].str.contains('child'), 'eligibility_criteria'][22]
# Out:
# '\n        Inclusion Criteria:\n\n          -  HCC diagnosed by positive biopsy or non-invasive criteria,\n\n          -  not suitable for surgical resection or transplantation,\n\n          -  have at least one, but less than or equal to 3 tumors,\n\n          -  of the tumour(s) identified, each tumor must be ≤ 3 cm in diameter,\n\n          -  Child-Pugh class A,\n\n          -  Eastern Cooperative Oncology Group (ECOG) score of 0,\n\n          -  American Society of Anaesthesiologists (ASA) score ≤ 3,\n\n          -  a prothrombin time ratio > 50%,\n\n          -  platelet count > 50x109/L,\n\n          -  ability of patient to stop anticoagulant and anti-platelet therapy for seven days\n             prior to and seven days post NanoKnife procedure,\n\n          -  are able to comprehend and willing to sign the written informed consent form (ICF),\n\n          -  have a life expectancy of at least 3 months.\n\n        Exclusion Criteria:\n\n          -  eligible for surgical treatment or transplantation for HCC,\n\n          -  presence of vascular invasion or extrahepatic metastases,\n\n          -  received previous treatment for HCC,\n\n          -  HCC developed on an already transplanted liver,\n\n          -  cardiac insufficiency, ongoing coronary artery disease or arrhythmia,\n\n          -  any active implanted device (eg Pacemaker),\n\n          -  women who are pregnant or women of child-bearing potential who are not using an\n             acceptable method of contraception,\n\n          -  have received treatment with an investigational agent/ procedure within 30 days prior\n             to treatment with the NanoKnife™ LEDC System,\n\n          -  are in the opinion of the Investigator unable to comply with the visit schedule and\n             protocol evaluations.\n      '
